# %% [markdown]
# # Data cleaning
# We have our raw dataset, now we need to make it ready for analysis

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import json
import warnings

# %% [markdown]
# ### Load raw dataset

# %%
raw = pd.read_csv("../00_raw/china_raw.csv", dtype={"cidade": str})
raw
# Out:
#         day    city                                          expense   price  \
# 0    12-May  Pequim            Didi pro templo do céu (tava fechado)   38.42
# 1    12-May  Pequim  Didi pro shopping das Pérolas (Hungqiao Market)   13.30
# 2    12-May  Pequim  Colar e brincos Carol + brinco presente da Lara  170.00
# 3    12-May  Pequim                                 Didi pra Qianmen   14.80
# 4    12-May  Pequim                                   Almoço Qianmen   64.00
# ..      ...     ...                                              ...     ...
# 125  29-May   Lhasa                                  Didi para Bokar     NaN
# 126  29-May   Lhasa                                           Almoço   33.00
# 127  29-May   Lhasa                        Compras Bokar Supermarket  105.00
# 128  29-May   Lhasa                            Massagem no aeroporto   30.00
# 129  29-May  Pequim                                Taxi do aeroporto  102.00
#
#     payment_source           category
# 0            Carol         Transporte
# 1            Carol         Transporte
# 2            Carol  Compras/Presentes
# 3            Carol         Transporte
# 4            Carol        Alimentação
# ..             ...                ...
# 125           Diva         Transporte
# 126           Diva        Alimentação
# 127          Carol  Compras/Presentes
# 128           Diva  Compras/Presentes
# 129          Paula         Transporte
#
# [130 rows x 6 columns]

# %% [markdown]
# ### Add missing rows
# When checking the AI generated dataset we noticed two issues:
# <br>
# 1- Some values are null
# <br>
# 2- Others are simply absent (from the dataset and the original source)
# <br>
# There's also a third issue:
# <br>
# 3- The price is sometimes for two people (Carol and Diva) and sometimes for three people (Carol, Diva and Renata). It's reasonable to say we want to find how much more one spends travelling to and in China.
# <br><br>
# The first issue was solved with **.apply()**:

# %%
# Issue 1: some expenses have an NA on the "price" column
no_price = raw.loc[pd.isna(raw["price"])]
no_price
# Out:
#         day      city               expense  price payment_source  \
# 51   17-May    Pequim                 Metrô    NaN           Diva
# 97   22-May    Pequim  Didi para Tiannanmen    NaN           Diva
# 98   22-May    Pequim       Almoço no museu    NaN           Diva
# 99   22-May    Pequim      Comprinhas museu    NaN           Diva
# 103  24-May     Lhasa    Didi pro aeroporto    NaN          Carol
# 112  27-May  Shigatse                Jantar    NaN          Carol
# 125  29-May     Lhasa       Didi para Bokar    NaN           Diva
#
#               category
# 51          Transporte
# 97          Transporte
# 98         Alimentação
# 99   Compras/Presentes
# 103         Transporte
# 112        Alimentação
# 125         Transporte

# %%
# Solution: apply and lambda
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 42 if "Didi para Tiannanmen" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 8 if "Metrô" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 165 if "Comprinhas museu" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 26 if "Almoço no museu" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 107 if "Didi pro aeroporto" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 52 if "Jantar" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 14 if "Didi para Bokar" in row["expense"] else pd.NA, axis=1)
raw
# Out:
# /var/folders/mp/9bbmxhdd5ms420hm5z9_6f000000gn/T/ipykernel_2341/3125365558.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[<NA> 42 <NA> <NA> <NA> <NA> <NA>]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
#         day    city                                          expense  price  \
# 0    12-May  Pequim            Didi pro templo do céu (tava fechado)  38.42
# 1    12-May  Pequim  Didi pro shopping das Pérolas (Hungqiao Market)   13.3
# 2    12-May  Pequim  Colar e brincos Carol + brinco presente da Lara  170.0
# 3    12-May  Pequim                                 Didi pra Qianmen   14.8
# 4    12-May  Pequim                                   Almoço Qianmen   64.0
# ..      ...     ...                                              ...    ...
# 125  29-May   Lhasa                                  Didi para Bokar     14
# 126  29-May   Lhasa                                           Almoço   33.0
# 127  29-May   Lhasa                        Compras Bokar Supermarket  105.0
# 128  29-May   Lhasa                            Massagem no aeroporto   30.0
# 129  29-May  Pequim                                Taxi do aeroporto  102.0
#
#     payment_source           category
# 0            Carol         Transporte
# 1            Carol         Transporte
# 2            Carol  Compras/Presentes
# 3            Carol         Transporte
# 4            Carol        Alimentação
# ..             ...                ...
# 125           Diva         Transporte
# 126           Diva        Alimentação
# 127          Carol  Compras/Presentes
# 128           Diva  Compras/Presentes
# 129          Paula         Transporte
#
# [130 rows x 6 columns]

# %% [markdown]
# I solved the second issue (values that are relevant expenses but weren't on the original notes) by creating those rows myself and including other major expenses that weren't kept on the original file, such as airfares, train tickets, hotels and tour agency packages. These were paid for in advance, but I kept the day they were used to make the timeline better.
# <br><br>
# I saved that file as a json called **missing_data.json**, so now i can add the rows to the raw dataset, and get a more completed dataframe:

# %%
# Open the json with the data that was still missing:
missing_data = pd.read_json("../00_raw/missing_data.json", dtype={"cidade": str})
missing_data.head(10)
# Out:
#       day       city                                 expense    price  \
# 0  13-May     Datong       Da Tong Weidu International Hotel   292.00
# 1  17-May     Suzhou                    HanTin Premium Hotel   656.00
# 2  18-May     Xangai                           Homeinn Hotel   970.00
# 3  18-May  Guangzhou     SunYat Sen University Kaifeng Hotel  1382.00
# 4  13-May     Datong              trem de Pequim para Datong   378.00
# 5  15-May     Datong              trem de Datong para Pequim   366.00
# 6  17-May     Suzhou              trem de Pequim para Suzhou  1224.00
# 7  18-May     Suzhou              trem de Suzhou para Xangai   168.00
# 8  20-May     Xangai             Avião de Xangai para Pequim  1460.00
# 9  24-May      Lhasa  Avião ida e volta de Pequim para Lhasa  9169.11
#
#   payment_source    category
# 0           Diva       Hotel
# 1         Renata       Hotel
# 2         Renata       Hotel
# 3         Renata       Hotel
# 4         Renata  Transporte
# 5         Renata  Transporte
# 6         Renata  Transporte
# 7         Renata  Transporte
# 8         Renata  Transporte
# 9          Paula  Transporte

# %%
# Now let's concatenate both datasets
df_concat = pd.concat([raw, missing_data])
df_concat
# Out:
#        day       city                                          expense  \
# 0   12-May     Pequim            Didi pro templo do céu (tava fechado)
# 1   12-May     Pequim  Didi pro shopping das Pérolas (Hungqiao Market)
# 2   12-May     Pequim  Colar e brincos Carol + brinco presente da Lara
# 3   12-May     Pequim                                 Didi pra Qianmen
# 4   12-May     Pequim                                   Almoço Qianmen
# ..     ...        ...                                              ...
# 31  02-Jun  Guangzhou                                             Didi
# 32  02-Jun     Pequim                                Didi do aeroporto
# 33  03-Jun     Pequim                                 Massagem nos pés
# 34  03-Jun     Pequim                            Didi para o aeroporto
# 35  03-Jun     Pequim                                 Taobao e Meituan
#
#      price payment_source           category
# 0    38.42          Carol         Transporte
# 1     13.3          Carol         Transporte
# 2    170.0          Carol  Compras/Presentes
# 3     14.8          Carol         Transporte
# 4     64.0          Carol        Alimentação
# ..     ...            ...                ...
# 31   18.79          Carol         Transporte
# 32   110.0         Renata         Transporte
# 33   156.0          Carol  Compras/presentes
# 34    90.0         Renata         Transporte
# 35  840.47         Renata  Compras/presentes
#
# [166 rows x 6 columns]

# %%
# And reorder the rows by day
df_concat = df_concat.sort_values("day")
df_concat
# Out:
#        day       city                                     expense   price  \
# 27  01-Jun  Guangzhou                                      Jantar   120.0
# 26  01-Jun  Guangzhou                    Cruzeiro Rio das Pérolas   369.0
# 23  01-Jun  Guangzhou                                      Almoço    90.0
# 22  01-Jun  Guangzhou             Carro do aeroporto para o hotel   130.0
# 32  02-Jun     Pequim                           Didi do aeroporto   110.0
# ..     ...        ...                                         ...     ...
# 18  30-May     Pequim                              Lenços de seda  1145.0
# 17  30-May     Pequim                  Almoço no bairro da Renata  1234.0
# 21  30-May     Pequim                                       Metrô    14.0
# 16  30-May     Pequim                                Supermercado    21.3
# 10  31-May  Guangzhou  Avião ida e volta de Pequim para Guangzhou  6150.0
#
#    payment_source           category
# 27           Diva        Alimentação
# 26         Renata          Ingressos
# 23           Diva        Alimentação
# 22         Renata         Transporte
# 32         Renata         Transporte
# ..            ...                ...
# 18          Paula  Compras/presentes
# 17           Diva        Alimentação
# 21          Paula         Transporte
# 16          Carol  Compras/presentes
# 10         Renata         Transporte
#
# [166 rows x 6 columns]

# %%
# Looks like our date format isn't helpful once there are two months involved.
# Let's fix it:
df_concat["day_cleaned"] = pd.Series(df_concat["day"])
df_concat["day_cleaned"] = pd.to_datetime(df_concat["day_cleaned"], format='%d-%b')
df_concat = df_concat.sort_values("day_cleaned", ascending=True)
df_concat["day_cleaned"] = df_concat["day_cleaned"].dt.strftime('%b-%d')
df_concat.drop("day", axis=1, inplace=True)

# %%
df = df_concat[["day_cleaned",
         "city",
         "expense",
         "price",
         "payment_source",
         "category"]]
df
# Out:
#    day_cleaned       city                                          expense  \
# 14      May-11     Pequim          Táxi do aeroporto para a casa da Renata
# 10      May-12     Pequim          Didi pro restaurante de dumpling fritos
# 2       May-12     Pequim  Colar e brincos Carol + brinco presente da Lara
# 8       May-12     Pequim                                       3 Baralhos
# 7       May-12     Pequim                                  Mountain Coffee
# ..         ...        ...                                              ...
# 31      Jun-02  Guangzhou                                             Didi
# 32      Jun-02     Pequim                                Didi do aeroporto
# 33      Jun-03     Pequim                                 Massagem nos pés
# 35      Jun-03     Pequim                                 Taobao e Meituan
# 34      Jun-03     Pequim                            Didi para o aeroporto
#
#      price payment_source           category
# 14    87.0          Carol         Transporte
# 10   49.93          Carol         Transporte
# 2    170.0          Carol  Compras/Presentes
# 8     90.0          Carol  Compras/Presentes
# 7     25.0          Carol        Alimentação
# ..     ...            ...                ...
# 31   18.79          Carol         Transporte
# 32   110.0         Renata         Transporte
# 33   156.0          Carol  Compras/presentes
# 35  840.47         Renata  Compras/presentes
# 34    90.0         Renata         Transporte
#
# [166 rows x 6 columns]

# %% [markdown]
# As for the third issue, I'm going to solve it using this logic:
# - On the cities only my mother and I visited (Beijing, Datong, Shanghai and Shigatse), I'll divide the price of expenses by 2.
# - On the other places (Suzhou, Lhasa and Guangzhou), I'll divide it by 3.

# %%
# Create a dataset only with the expenses in Beijing, Datong, Shanghai and Shigatse and divide the price by TWO:
trip_for_two = df[df['city'].isin(['Pequim', 'Datong', 'Shanghai', 'Shigatse'])]
trip_for_two["price"].astype(float)
trip_for_two["price_per_capita"] = trip_for_two["price"]/2
trip_for_two
# Out:
# /var/folders/mp/9bbmxhdd5ms420hm5z9_6f000000gn/T/ipykernel_2341/3479853598.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_for_two["price_per_capita"] = trip_for_two["price"]/2
#    day_cleaned    city                                          expense  \
# 14      May-11  Pequim          Táxi do aeroporto para a casa da Renata
# 10      May-12  Pequim          Didi pro restaurante de dumpling fritos
# 2       May-12  Pequim  Colar e brincos Carol + brinco presente da Lara
# 8       May-12  Pequim                                       3 Baralhos
# 7       May-12  Pequim                                  Mountain Coffee
# ..         ...     ...                                              ...
# 16      May-30  Pequim                                     Supermercado
# 32      Jun-02  Pequim                                Didi do aeroporto
# 33      Jun-03  Pequim                                 Massagem nos pés
# 35      Jun-03  Pequim                                 Taobao e Meituan
# 34      Jun-03  Pequim                            Didi para o aeroporto
#
#      price payment_source           category price_per_capita
# 14    87.0          Carol         Transporte             43.5
# 10   49.93          Carol         Transporte           24.965
# 2    170.0          Carol  Compras/Presentes             85.0
# 8     90.0          Carol  Compras/Presentes             45.0
# 7     25.0          Carol        Alimentação             12.5
# ..     ...            ...                ...              ...
# 16    21.3          Carol  Compras/presentes            10.65
# 32   110.0         Renata         Transporte             55.0
# 33   156.0          Carol  Compras/presentes             78.0
# 35  840.47         Renata  Compras/presentes          420.235
# 34    90.0         Renata         Transporte             45.0
#
# [96 rows x 7 columns]

# %%
# Create a dataset only with the expenses in Suzhou, Lhasa and Guangzhou and divide the price by THREE:
trip_for_three = df[df['city'].isin(['Suzhou', 'Lhasa', 'Guangzhou'])]
trip_for_three["price"].astype(float)
trip_for_three["price_per_capita"] = trip_for_three["price"]/3
trip_for_three
# Out:
# /var/folders/mp/9bbmxhdd5ms420hm5z9_6f000000gn/T/ipykernel_2341/1481526534.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_for_three["price_per_capita"] = trip_for_three["price"]/3
#     day_cleaned       city                                     expense  \
# 1        May-17     Suzhou                        HanTin Premium Hotel
# 6        May-17     Suzhou                  trem de Pequim para Suzhou
# 7        May-18     Suzhou                  trem de Suzhou para Xangai
# 3        May-18  Guangzhou         SunYat Sen University Kaifeng Hotel
# 55       May-18     Suzhou                                       Metro
# 57       May-18     Suzhou     Entrada Jardim do Administrador Humilde
# 58       May-18     Suzhou                               Cartão-postal
# 59       May-18     Suzhou                       Café espresso + leite
# 56       May-18     Suzhou     Entrada Jardim do Administrador Humilde
# 105      May-24      Lhasa                      Show Princesa Wejcheng
# 103      May-24      Lhasa                          Didi pro aeroporto
# 104      May-24      Lhasa                     Almoço hot pot surpresa
# 106      May-24      Lhasa                                     Comidas
# 13       May-24      Lhasa                     Pacote de turismo Tibet
# 9        May-24      Lhasa      Avião ida e volta de Pequim para Lhasa
# 11       May-24      Lhasa  Avião ida e volta de São Paulo para Pequim
# 109      May-25      Lhasa                                      Bolsas
# 108      May-25      Lhasa                         Porta-incenso e ímã
# 107      May-25      Lhasa                     Proteção (Jokar Temple)
# 110      May-26      Lhasa                          Comprinhas mirante
# 128      May-29      Lhasa                       Massagem no aeroporto
# 125      May-29      Lhasa                             Didi para Bokar
# 124      May-29      Lhasa                         Compras Norbulingka
# 123      May-29      Lhasa                         Entrada Norbulingka
# 122      May-29      Lhasa                       Didi para Norbulingka
# 127      May-29      Lhasa                   Compras Bokar Supermarket
# 126      May-29      Lhasa                                      Almoço
# 10       May-31  Guangzhou  Avião ida e volta de Pequim para Guangzhou
# 22       Jun-01  Guangzhou             Carro do aeroporto para o hotel
# 23       Jun-01  Guangzhou                                      Almoço
# 26       Jun-01  Guangzhou                    Cruzeiro Rio das Pérolas
# 27       Jun-01  Guangzhou                                      Jantar
# 24       Jun-02  Guangzhou                                    Livraria
# 25       Jun-02  Guangzhou                       Café latte no M Stand
# 28       Jun-02  Guangzhou                                       Museu
# 29       Jun-02  Guangzhou                                        Didi
# 30       Jun-02  Guangzhou                           Comprinhas Miniso
# 31       Jun-02  Guangzhou                                        Didi
#
#        price payment_source           category price_per_capita
# 1      656.0         Renata              Hotel       218.666667
# 6     1224.0         Renata         Transporte            408.0
# 7      168.0         Renata         Transporte             56.0
# 3     1382.0         Renata              Hotel       460.666667
# 55       4.0           Diva         Transporte         1.333333
# 57      40.0           Diva          Ingressos        13.333333
# 58      10.0          Carol  Compras/Presentes         3.333333
# 59      20.0           Diva        Alimentação         6.666667
# 56      80.0          Carol          Ingressos        26.666667
# 105    840.0           Tica          Ingressos            280.0
# 103      107          Carol         Transporte        35.666667
# 104    438.0           Tica        Alimentação            146.0
# 106     30.0   Carol/Renata        Alimentação             10.0
# 13   15183.0          Paula            Agência           5061.0
# 9    9169.11          Paula         Transporte          3056.37
# 11   23791.9          Paula         Transporte      7930.633333
# 109    120.0           Tica  Compras/Presentes             40.0
# 108     76.0           Diva  Compras/Presentes        25.333333
# 107     50.0         Renata  Compras/Presentes        16.666667
# 110    150.0           Diva  Compras/Presentes             50.0
# 128     30.0           Diva  Compras/Presentes             10.0
# 125       14           Diva         Transporte         4.666667
# 124    308.0           Diva  Compras/Presentes       102.666667
# 123    120.0           Diva          Ingressos             40.0
# 122     15.0           Diva         Transporte              5.0
# 127    105.0          Carol  Compras/Presentes             35.0
# 126     33.0           Diva        Alimentação             11.0
# 10    6150.0         Renata         Transporte           2050.0
# 22     130.0         Renata         Transporte        43.333333
# 23      90.0           Diva        Alimentação             30.0
# 26     369.0         Renata          Ingressos            123.0
# 27     120.0           Diva        Alimentação             40.0
# 24      11.5          Carol  Compras/presentes         3.833333
# 25      45.0           Diva        Alimentação             15.0
# 28      10.0          Carol          Ingressos         3.333333
# 29      17.1          Carol         Transporte              5.7
# 30      15.0          Carol  Compras/presentes              5.0
# 31     18.79          Carol         Transporte         6.263333

# %%
# Concatenate the rows from the two datasets
df = pd.concat([trip_for_two, trip_for_three]).sort_values("day_cleaned")
df
# Out:
#    day_cleaned       city                                     expense   price  \
# 27      Jun-01  Guangzhou                                      Jantar   120.0
# 26      Jun-01  Guangzhou                    Cruzeiro Rio das Pérolas   369.0
# 23      Jun-01  Guangzhou                                      Almoço    90.0
# 22      Jun-01  Guangzhou             Carro do aeroporto para o hotel   130.0
# 31      Jun-02  Guangzhou                                        Didi   18.79
# ..         ...        ...                                         ...     ...
# 20      May-30     Pequim                                Supermercado   19.39
# 19      May-30     Pequim                   Brincos e colar de pérola  1234.0
# 18      May-30     Pequim                              Lenços de seda  1145.0
# 17      May-30     Pequim                  Almoço no bairro da Renata  1234.0
# 10      May-31  Guangzhou  Avião ida e volta de Pequim para Guangzhou  6150.0
#
#    payment_source           category price_per_capita
# 27           Diva        Alimentação             40.0
# 26         Renata          Ingressos            123.0
# 23           Diva        Alimentação             30.0
# 22         Renata         Transporte        43.333333
# 31          Carol         Transporte         6.263333
# ..            ...                ...              ...
# 20          Carol        Alimentação            9.695
# 19           Diva  Compras/presentes            617.0
# 18          Paula  Compras/presentes            572.5
# 17           Diva        Alimentação            617.0
# 10         Renata         Transporte           2050.0
#
# [134 rows x 7 columns]

# %% [markdown]
# Now, for the final part in getting the data tidy, I'm going to specified the payment type.
# <br><br>
# This is important because China, unlike the US and Brazil, has the so-called superapps, such as Alipay, used to call a Didi, take the metro, order at restaurants and pay for things in stores, or WeChat, more common in more remote locations when a business or vendor wouldn't accept Alipay.
# <br><br>
# I can do this because I know that all expenses that have "Paula" as payment_source were paid for using our credit cards connected to Paula's bank account in the US.
# <br><br>
# And all the other names mean that the payment was made using Alipay, WeChat or other app purchases, like Taobao and Meituan. The money comes from Renata's bank account in China and stays in a digital wallet inside the apps.
# <br><br>
# I want to see **how much we've spent in total from each payment type**, and the *average spent in each purchase* from these two groups.

# %%
# Create new column "payment_type" and filling it according to the values in column "payment_source"
df["payment_type"] = df["payment_source"].apply(lambda x: "credit card" if x == "Paula" else "apps")
df
# Out:
#    day_cleaned       city                                     expense   price  \
# 27      Jun-01  Guangzhou                                      Jantar   120.0
# 26      Jun-01  Guangzhou                    Cruzeiro Rio das Pérolas   369.0
# 23      Jun-01  Guangzhou                                      Almoço    90.0
# 22      Jun-01  Guangzhou             Carro do aeroporto para o hotel   130.0
# 31      Jun-02  Guangzhou                                        Didi   18.79
# ..         ...        ...                                         ...     ...
# 20      May-30     Pequim                                Supermercado   19.39
# 19      May-30     Pequim                   Brincos e colar de pérola  1234.0
# 18      May-30     Pequim                              Lenços de seda  1145.0
# 17      May-30     Pequim                  Almoço no bairro da Renata  1234.0
# 10      May-31  Guangzhou  Avião ida e volta de Pequim para Guangzhou  6150.0
#
#    payment_source           category price_per_capita payment_type
# 27           Diva        Alimentação             40.0         apps
# 26         Renata          Ingressos            123.0         apps
# 23           Diva        Alimentação             30.0         apps
# 22         Renata         Transporte        43.333333         apps
# 31          Carol         Transporte         6.263333         apps
# ..            ...                ...              ...          ...
# 20          Carol        Alimentação            9.695         apps
# 19           Diva  Compras/presentes            617.0         apps
# 18          Paula  Compras/presentes            572.5  credit card
# 17           Diva        Alimentação            617.0         apps
# 10         Renata         Transporte           2050.0         apps
#
# [134 rows x 8 columns]

# %% [markdown]
# Just some final steps to get the dataframe as tidy as possible:

# %%
# Rename the column "day_cleaned" to "date" so it's tidier
df = df.rename(columns={ "day_cleaned": "date"} )
df["price"] = df["price"].astype(float)
df["price"] = df["price"].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 166 entries, 14 to 34
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            166 non-null    object
#  1   city            166 non-null    object
#  2   expense         166 non-null    object
#  3   price           166 non-null    float64
#  4   payment_source  166 non-null    object
#  5   category        166 non-null    object
#  6   payment_type    166 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 10.4+ KB

# %% [markdown]
# Okay, now my dataframe is ready for the analyses I wanna do.

# %%
df.to_csv("../04_tidy_data/china_df.csv", index=False)
